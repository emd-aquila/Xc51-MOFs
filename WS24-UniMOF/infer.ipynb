# %% [markdown]
# # Inference with UniMOF Model for WS24
#
# This notebook demonstrates how to do inference on a finetuned UniMOF model to predict water adsorption behaviors.

# %%
#@title Install Uni-Core and dependencies
# %%bash
cd /content

# install dependencies if not done already
if [ ! -f ENV_READY ]; then
    pip3 install rdkit
    pip3 install lmdb
    pip3 install pymatgen
    touch ENV_READY
fi

UNICORE_GIT='https://github.com/dptech-corp/Uni-Core.git'
WS24_UNIMOF_GIT='https://github.com/emd-aquila/Xc51-MOFs.git'

# install Uni-Core if not done already
if [ ! -f UNICORE_READY ]; then
    git clone -b main ${UNICORE_GIT}
    # fix error in code before installing
    perl -pi -e 's/state = torch\.load\(f, map_location=torch\.device\("cpu"\)\)/state = torch.load(f, map_location=torch.device("cpu"), weights_only=False)/' ./Uni-Core/unicore/checkpoint_utils.py
    pip3 install -e ./Uni-Core
    git clone -b main ${WS24_UNIMOF_GIT}
    touch UNICORE_READY
fi
# Out:
# Collecting rdkit
#   Downloading rdkit-2025.3.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (4.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from rdkit) (11.2.1)
# Downloading rdkit-2025.3.1-cp311-cp311-manylinux_2_28_x86_64.whl (34.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.6/34.6 MB 51.8 MB/s eta 0:00:00
# Installing collected packages: rdkit
# Successfully installed rdkit-2025.3.1
# Collecting lmdb
#   Downloading lmdb-1.6.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Downloading lmdb-1.6.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (297 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.8/297.8 kB 5.4 MB/s eta 0:00:00
# Installing collected packages: lmdb
# Successfully installed lmdb-1.6.2
# Collecting pymatgen
#   Downloading pymatgen-2025.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: joblib>=1 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (1.4.2)
# Requirement already satisfied: matplotlib>=3.8 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (3.10.0)
# Collecting monty>=2025.1.9 (from pymatgen)
#   Downloading monty-2025.3.3-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (3.4.2)
# Collecting palettable>=3.3.3 (from pymatgen)
#   Downloading palettable-3.3.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pandas>=2 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (2.2.2)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (5.24.1)
# Collecting bibtexparser>=1.4.0 (from pymatgen)
#   Downloading bibtexparser-1.4.3.tar.gz (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: requests>=2.32 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (2.32.3)
# Collecting ruamel.yaml>=0.17.0 (from pymatgen)
#   Downloading ruamel.yaml-0.18.10-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: scipy>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (1.15.2)
# Collecting spglib>=2.5 (from pymatgen)
#   Downloading spglib-2.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: sympy>=1.3 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (1.13.1)
# Requirement already satisfied: tabulate>=0.9 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (0.9.0)
# Requirement already satisfied: tqdm>=4.60 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (4.67.1)
# Collecting uncertainties>=3.1.4 (from pymatgen)
#   Downloading uncertainties-3.2.3-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: numpy<3,>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from pymatgen) (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.11/dist-packages (from bibtexparser>=1.4.0->pymatgen) (3.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen) (11.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.8->pymatgen) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2->pymatgen) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2->pymatgen) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.0.0->pymatgen) (9.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32->pymatgen) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32->pymatgen) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32->pymatgen) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32->pymatgen) (2025.4.26)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.0->pymatgen)
#   Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from spglib>=2.5->pymatgen) (4.13.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.3->pymatgen) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.8->pymatgen) (1.17.0)
# Downloading pymatgen-2025.5.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 49.4 MB/s eta 0:00:00
# Downloading monty-2025.3.3-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 4.5 MB/s eta 0:00:00
# Downloading palettable-3.3.3-py2.py3-none-any.whl (332 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 29.4 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.18.10-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 11.6 MB/s eta 0:00:00
# Downloading spglib-2.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (809 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.0/809.0 kB 55.8 MB/s eta 0:00:00
# Downloading uncertainties-3.2.3-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 5.5 MB/s eta 0:00:00
# Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (739 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 50.8 MB/s eta 0:00:00
# Building wheels for collected packages: bibtexparser
#   Building wheel for bibtexparser (setup.py): started
#   Building wheel for bibtexparser (setup.py): finished with status 'done'
#   Created wheel for bibtexparser: filename=bibtexparser-1.4.3-py3-none-any.whl size=43549 sha256=3be9da37cf89e25fb53272e99e9b199ad42456bf37c84e0a948942dbd5a91fb5
#   Stored in directory: /root/.cache/pip/wheels/16/fb/76/306387739cf9d53b1c39b0c8aadbbb17dc05f256756d8fd915
# Successfully built bibtexparser
# Installing collected packages: uncertainties, spglib, ruamel.yaml.clib, palettable, bibtexparser, ruamel.yaml, monty, pymatgen
# Successfully installed bibtexparser-1.4.3 monty-2025.3.3 palettable-3.3.3 pymatgen-2025.5.2 ruamel.yaml-0.18.10 ruamel.yaml.clib-0.2.12 spglib-2.6.0 uncertainties-3.2.3
# Obtaining file:///content/Uni-Core
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from unicore==0.0.1) (2.0.2)
# Requirement already satisfied: lmdb in /usr/local/lib/python3.11/dist-packages (from unicore==0.0.1) (1.6.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from unicore==0.0.1) (4.67.1)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from unicore==0.0.1) (2.6.0+cu124)
# Collecting ml_collections (from unicore==0.0.1)
#   Downloading ml_collections-1.1.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from unicore==0.0.1) (1.15.2)
# Collecting tensorboardX (from unicore==0.0.1)
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.11/dist-packages (from unicore==0.0.1) (0.21.1)
# Requirement already satisfied: wandb in /usr/local/lib/python3.11/dist-packages (from unicore==0.0.1) (0.19.10)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->unicore==0.0.1) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->unicore==0.0.1) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->unicore==0.0.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->unicore==0.0.1) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->unicore==0.0.1) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=2.0.0->unicore==0.0.1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=2.0.0->unicore==0.0.1)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=2.0.0->unicore==0.0.1)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=2.0.0->unicore==0.0.1)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=2.0.0->unicore==0.0.1)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=2.0.0->unicore==0.0.1)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=2.0.0->unicore==0.0.1)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=2.0.0->unicore==0.0.1)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=2.0.0->unicore==0.0.1)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->unicore==0.0.1) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->unicore==0.0.1) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->unicore==0.0.1) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=2.0.0->unicore==0.0.1)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->unicore==0.0.1) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->unicore==0.0.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->unicore==0.0.1) (1.3.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from ml_collections->unicore==0.0.1) (1.4.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from ml_collections->unicore==0.0.1) (6.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorboardX->unicore==0.0.1) (24.2)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.11/dist-packages (from tensorboardX->unicore==0.0.1) (5.29.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers->unicore==0.0.1) (0.30.2)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.11/dist-packages (from wandb->unicore==0.0.1) (8.1.8)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from wandb->unicore==0.0.1) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->unicore==0.0.1) (3.1.44)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.11/dist-packages (from wandb->unicore==0.0.1) (4.3.7)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->unicore==0.0.1) (5.9.5)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.11/dist-packages (from wandb->unicore==0.0.1) (2.11.4)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->unicore==0.0.1) (2.32.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from wandb->unicore==0.0.1) (2.27.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.11/dist-packages (from wandb->unicore==0.0.1) (1.3.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from wandb->unicore==0.0.1) (75.2.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from docker-pycreds>=0.4.0->wandb->unicore==0.0.1) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython!=3.1.29,>=1.0.0->wandb->unicore==0.0.1) (4.0.12)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb->unicore==0.0.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb->unicore==0.0.1) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3->wandb->unicore==0.0.1) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb->unicore==0.0.1) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb->unicore==0.0.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb->unicore==0.0.1) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.0.0->wandb->unicore==0.0.1) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->unicore==0.0.1) (3.0.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb->unicore==0.0.1) (5.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 120.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 88.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 50.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 42.4 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 19.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 4.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.1 MB/s eta 0:00:00
# Downloading ml_collections-1.1.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 7.5 MB/s eta 0:00:00
# Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 9.4 MB/s eta 0:00:00
# Installing collected packages: tensorboardX, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, ml_collections, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, unicore
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Running setup.py develop for unicore
# Successfully installed ml_collections-1.1.0 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 tensorboardX-2.6.2.2 unicore-0.0.1
# Cloning into 'Uni-Core'...
# Cloning into 'Xc51-MOFs'...

# %% [markdown]
# ## (optional) download a checkpoint from Dropbox
# Find the checkpoint you want to download from the Dropbox, and copy the link here.

# %%
# !wget 'https://www.dropbox.com/scl/fi/0fzemjaybokz673qqqeb9/checkpoint.best_f1_0.26.pt?rlkey=4vjtzmtcrqv00aj88lelqm5wf&st=93oljhun&dl=0' -O checkpoint.best_f1_0.26.pt

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# %cd /content/drive/MyDrive/Xc51-MOFs/WS24-UniMOF
# Out:
# /content/drive/MyDrive/Xc51-MOFs/WS24-UniMOF

# %% [markdown]
# ## Inference

# %%
# !chmod +x inference_scripts/infer-mostly-freeze-weighted.sh

# %%
# !./inference_scripts/infer-mostly-freeze-weighted.sh
# Out:
# 2025-05-12 15:31:47.362321: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1747063907.384507    1445 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1747063907.391162    1445 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-12 15:31:47.412807: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# fused_multi_tensor is not installed corrected
# fused_rounding is not installed corrected
# fused_layer_norm is not installed corrected
# fused_rms_norm is not installed corrected
# fused_softmax is not installed corrected
# 2025-05-12 15:32:04 | INFO | unimat.inference | loading model(s) from ./logs_mostly_freeze_weighted/checkpoint.best_f1_0.48.pt
# 2025-05-12 15:32:06 | INFO | unimat.tasks.unimof_ws24 | dictionary: 80 types
# 2025-05-12 15:32:07 | INFO | unimat.inference | Namespace(no_progress_bar=False, log_interval=1000, log_format=None, tensorboard_logdir='', wandb_project='', wandb_name='', seed=1, cpu=False, fp16=True, bf16=False, bf16_sr=False, allreduce_fp32_grad=False, fp16_no_flatten_grads=False, fp16_init_scale=4, fp16_scale_window=256, fp16_scale_tolerance=0.0, min_loss_scale=0.0001, threshold_loss_scale=None, user_dir='./unimat', empty_cache_freq=0, all_gather_list_size=16384, suppress_crashes=False, profile=False, ema_decay=-1.0, validate_with_ema=False, loss='cross_entropy_ws24', optimizer='adam', lr_scheduler='fixed', task='unimof_ws24', num_workers=0, skip_invalid_size_inputs_valid_test=False, batch_size=1, required_batch_size_multiple=1, data_buffer_size=10, train_subset='train', valid_subset='train,valid,test', validate_interval=1, validate_interval_updates=0, validate_after_updates=0, fixed_validation_seed=None, disable_validation=False, batch_size_valid=1, max_valid_steps=None, curriculum=0, distributed_world_size=1, distributed_rank=0, distributed_backend='nccl', distributed_init_method=None, distributed_port=-1, device_id=0, distributed_no_spawn=False, ddp_backend='c10d', bucket_cap_mb=25, fix_batches_to_gpus=False, find_unused_parameters=False, fast_stat_sync=False, broadcast_buffers=False, nprocs_per_node=1, path='./logs_mostly_freeze_weighted/checkpoint.best_f1_0.48.pt', quiet=False, model_overrides='{}', results_path='./evaluation_mostly_freeze_weighted', arch='unimof_ws24_mostly_freeze', hidden_dim=128, pooler_activation_fn='tanh', pooler_dropout=0.1, data='.', task_name='WS24', classification_head_name='classification', num_classes=4, max_atoms=512, dict_name='dict.txt', remove_hydrogen=True, finetune_mol_model=None, weight_by_class=False, adam_betas='(0.9, 0.999)', adam_eps=1e-08, weight_decay=0.0, force_anneal=None, lr_shrink=0.1, warmup_updates=0, no_seed_provided=False, encoder_layers=8, encoder_embed_dim=512, encoder_ffn_embed_dim=2048, encoder_attention_heads=64, dropout=0.1, emb_dropout=0.1, attention_dropout=0.1, activation_dropout=0.0, max_seq_len=1024, activation_fn='gelu', post_ln=False, masked_token_loss=-1.0, masked_coord_loss=-1.0, masked_dist_loss=-1.0, x_norm_loss=-1.0, delta_pair_repr_norm_loss=-1.0, lattice_loss=-1.0, distributed_num_procs=1)
# 2025-05-12 15:32:07 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2025-05-12 15:32:22 | INFO | unimat.inference | Done inference!
# 2025-05-12 15:32:22 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2025-05-12 15:32:24 | INFO | unimat.inference | Done inference!
# 2025-05-12 15:32:24 | INFO | unicore.tasks.unicore_task | get EpochBatchIterator for epoch 1
# 2025-05-12 15:32:26 | INFO | unimat.inference | Done inference!

# %%
import os

# Get the current working directory
current_directory = os.getcwd()
print("Current directory:", current_directory)
# Out:
# Current directory: /content/drive/MyDrive/Xc51-MOFs/WS24-UniMOF

# %%
import pickle
# Load and inspect the pickle file
with open('./evaluation/logs_train_tsne_.out.pkl', 'rb') as file:
    train_data = pickle.load(file)

with open('./evaluation/logs_valid_tsne_.out.pkl', 'rb') as file:
    valid_data = pickle.load(file)

with open('./evaluation/logs_test_tsne_.out.pkl', 'rb') as file:
    test_data = pickle.load(file)

# Display the contents of the loaded data
print(test_data)
# Out:
# [{'loss': 0.430419921875, 'logits': tensor([[-3.6367, -0.1173,  2.5176,  1.7500]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 3.740234375, 'logits': tensor([[-2.3711,  2.5410,  1.6777, -0.8174]], dtype=torch.float16), 'predict': tensor([2]), 'target': tensor([4.]), 'bsz': 1, 'sample_size': 1}, {'loss': 5.3828125, 'logits': tensor([[-0.4792, -0.5312,  3.0352, -2.2871]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([4.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.60546875, 'logits': tensor([[ 0.5254,  0.9966,  1.6738, -3.2969]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.018707275390625, 'logits': tensor([[-2.3965, -0.5586,  4.1641, -0.5947]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.5087890625, 'logits': tensor([[-3.3828,  1.9805,  2.4707, -0.5728]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 1.3076171875, 'logits': tensor([[ 1.9629,  1.0850, -0.5171, -1.3252]], dtype=torch.float16), 'predict': tensor([1]), 'target': tensor([2.]), 'bsz': 1, 'sample_size': 1}, {'loss': 1.5107421875, 'logits': tensor([[-1.8379,  2.3457,  1.1631, -0.3574]], dtype=torch.float16), 'predict': tensor([2]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 5.08203125, 'logits': tensor([[-2.2617, -0.4380,  4.1836, -0.8823]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([4.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.04400634765625, 'logits': tensor([[-1.6016, -0.2175, -0.8398,  3.4648]], dtype=torch.float16), 'predict': tensor([4]), 'target': tensor([4.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.57666015625, 'logits': tensor([[-0.9106,  0.5894,  1.6553,  0.6313]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 4.27734375, 'logits': tensor([[-2.2402, -0.0828,  4.1719, -1.0850]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([2.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.043121337890625, 'logits': tensor([[-3.0898,  0.4067,  3.7734, -0.9927]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 2.26171875, 'logits': tensor([[-3.0820,  1.2412,  3.3828, -1.3643]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([2.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.26416015625, 'logits': tensor([[-2.9688,  1.7500,  2.9980, -1.3730]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 4.78125, 'logits': tensor([[-1.2695, -1.3096,  3.4629, -0.0148]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([1.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.5625, 'logits': tensor([[ 1.6143, -1.8584,  1.2441, -1.7832]], dtype=torch.float16), 'predict': tensor([1]), 'target': tensor([1.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.0293121337890625, 'logits': tensor([[ 3.5879, -0.3938, -1.4287, -1.8252]], dtype=torch.float16), 'predict': tensor([1]), 'target': tensor([1.]), 'bsz': 1, 'sample_size': 1}, {'loss': 1.2978515625, 'logits': tensor([[ 0.8452,  1.4688,  0.4893, -1.5215]], dtype=torch.float16), 'predict': tensor([2]), 'target': tensor([1.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.0257415771484375, 'logits': tensor([[ 3.7168, -0.4915, -1.7725, -1.2344]], dtype=torch.float16), 'predict': tensor([1]), 'target': tensor([1.]), 'bsz': 1, 'sample_size': 1}, {'loss': 5.30859375, 'logits': tensor([[-1.5146, -0.1367,  3.7656, -1.7920]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([1.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.25537109375, 'logits': tensor([[ 2.1191,  0.4814, -0.4587, -1.7637]], dtype=torch.float16), 'predict': tensor([1]), 'target': tensor([1.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.0201263427734375, 'logits': tensor([[ 3.9043 ...
#        dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.021484375, 'logits': tensor([[-2.5977, -0.2098,  4.0703, -0.9487]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.479248046875, 'logits': tensor([[-2.7461,  2.0469,  2.5645, -1.7090]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.9755859375, 'logits': tensor([[ 0.3203,  0.9668,  0.9966, -0.7583]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 3.837890625, 'logits': tensor([[-0.9526,  3.8496,  0.0444, -1.9688]], dtype=torch.float16), 'predict': tensor([2]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 1.025390625, 'logits': tensor([[-0.0572,  1.0537,  0.9131, -0.4424]], dtype=torch.float16), 'predict': tensor([2]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 3.62109375, 'logits': tensor([[ 0.7817,  3.1055, -0.3904, -2.1367]], dtype=torch.float16), 'predict': tensor([2]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 1.072265625, 'logits': tensor([[-0.7656,  2.1172,  1.5518, -1.2295]], dtype=torch.float16), 'predict': tensor([2]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.78369140625, 'logits': tensor([[-0.9170,  1.4092,  1.4863, -0.2688]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.63427734375, 'logits': tensor([[-2.4941,  1.7598,  2.1484,  0.5293]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.02923583984375, 'logits': tensor([[-1.5068, -0.1249,  3.7578, -1.7891]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.83203125, 'logits': tensor([[-0.5742,  0.8403,  1.1914,  0.3301]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.0885009765625, 'logits': tensor([[-1.9805,  0.7793,  3.2676, -2.1992]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.07232666015625, 'logits': tensor([[-1.9229,  0.6753,  3.3945, -2.0820]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.0206146240234375, 'logits': tensor([[-2.4844, -0.1434,  4.1641, -0.9399]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 1.24609375, 'logits': tensor([[-0.9614,  0.9292,  0.6802,  0.6802]], dtype=torch.float16), 'predict': tensor([2]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.45703125, 'logits': tensor([[-2.4141,  1.7334,  2.4082, -0.3726]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.037017822265625, 'logits': tensor([[-2.7793,  0.4272,  3.9277, -1.1396]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.0244598388671875, 'logits': tensor([[-2.5664, -0.0635,  4.0391, -0.9404]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.19189453125, 'logits': tensor([[-2.6621,  1.5859,  3.1895, -1.7109]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.77197265625, 'logits': tensor([[-2.8125,  2.3320,  2.2148, -1.1973]], dtype=torch.float16), 'predict': tensor([2]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.367431640625, 'logits': tensor([[ 0.4553,  0.1945,  1.8857, -1.9990]], dtype=torch.float16), 'predict': tensor([3]), 'target': tensor([3.]), 'bsz': 1, 'sample_size': 1}, {'loss': 0.1990966796875, 'logits': tensor([[-2.4102,  1.4512,  3.0137, -2.0645]], dtype=torch.float16), 'predi ...

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
from sklearn.preprocessing import label_binarize

# Suppose all your outputs are gathered like this:
all_preds = []
all_targets = []
all_logits = []

# During inference, collect from each batch
for log in logging_outputs:
    all_preds.append(log["predict"])
    all_targets.append(log["target"])
    all_logits.append(log["logits"])

# Concatenate
y_pred = torch.cat(all_preds).numpy()
y_true = torch.cat(all_targets).numpy()
y_logits = torch.cat(all_logits).numpy()  # shape: (N, num_classes)

# -------- 1. Confusion Matrix --------
plt.figure(figsize=(6, 5))
cm = confusion_matrix(y_true, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=range(1, 5), yticklabels=range(1, 5))
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# -------- 2. AUC-ROC Curves (Multiclass) --------
# Binarize targets for ROC curve
num_classes = y_logits.shape[1]
y_true_bin = label_binarize(y_true, classes=range(num_classes))  # e.g., [0, 1, 2, 3]

fpr = {}
tpr = {}
roc_auc = {}

for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_logits[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot
plt.figure(figsize=(8, 6))
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label=f"Class {i} (AUC = {roc_auc[i]:.2f})")

plt.plot([0, 1], [0, 1], 'k--')  # chance
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve (Multiclass)")
plt.legend()
plt.grid(True)
plt.show()
